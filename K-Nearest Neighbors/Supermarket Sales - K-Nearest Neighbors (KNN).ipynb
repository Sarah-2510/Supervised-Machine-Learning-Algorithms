# %%
#Reading the libraries
import pandas as pd # data analytical library
import numpy as np #fast linear algebra
import matplotlib.pyplot as plt #visualization
import seaborn as sns #statistical visualization

# %%
#Reading the dataset
df=pd.read_csv("supermarket_sales.csv")

# %%
#checking the head of the dataset
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# 2  03-03-2019  13:23  Credit card  324.31                 4.761905
# 3   1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4  02-08-2019  10:37      Ewallet  604.17                 4.761905
#
#    gross income  Rating
# 0       26.1415     9.1
# 1        3.8200     9.6
# 2       16.2155     7.4
# 3       23.2880     8.4
# 4       30.2085     5.3

# %%
#checking the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# 75%               4.761905e+00     22.445250     8.50000
# max               4.761905e+00     49.650000    10.00000

# %%
#checking the data types
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
#Checking the shape of the dataset
df.shape
# Out:
# (1000, 17)

# %%
#Checking for null values
df.isna()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False     False   False  False  False  False    False  False
# 1         False     False   False  False  False  False    False  False
# 2         False     False   False  False  False  False    False  False
# 3         False     False   False  False  False  False    False  False
# 4         False     False   False  False  False  False    False  False
# ..          ...       ...     ...    ...    ...    ...      ...    ...
# 995       False     False   False  False  False  False    False  False
# 996       False     False   False  False  False  False    False  False
# 997       False     False   False  False  False  False    False  False
# 998       False     False   False  False  False  False    False  False
# 999       False     False   False  False  False  False    False  False
#
#      gross margin percentage  gross income  Rating
# 0                      False         False   False
# 1                      False         False   False
# 2                      False         False   False
# 3                      False         False   False
# 4                      False         False   False
# ..                       ...           ...     ...
# 995                    False         False   False
# 996                    False         False   False
# 997                    False         False   False
# 998                    False         False   False
# 999                    False         False   False
#
# [1000 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
df['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
df['Date']
# Out:
# 0      01-05-2019
# 1      03-08-2019
# 2      03-03-2019
# 3       1/27/2019
# 4      02-08-2019
#           ...
# 995     1/29/2019
# 996    03-02-2019
# 997    02-09-2019
# 998     2/22/2019
# 999     2/18/2019
# Name: Date, Length: 1000, dtype: object

# %%
pd.to_datetime(df['Date'])
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
#changing the data type of date from object to date-time
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(8)
# memory usage: 132.9+ KB

# %%
df['Time']
# Out:
# 0      13:08
# 1      10:29
# 2      13:23
# 3      20:33
# 4      10:37
#        ...
# 995    13:46
# 996    17:16
# 997    13:22
# 998    15:33
# 999    13:28
# Name: Time, Length: 1000, dtype: object

# %%
df['Date_time'] = df['Date'].astype(str) +' '+ df['Time'].astype(str)

# %%
(pd.to_datetime(df['Date_time']).dt.month).value_counts()
# Out:
# 1    352
# 3    345
# 2    303
# Name: Date_time, dtype: int64

# %%
(pd.to_datetime(df['Date_time']).dt.year).value_counts()
# Out:
# 2019    1000
# Name: Date_time, dtype: int64

# %%
(pd.to_datetime(df['Date_time']).dt.month).value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
pd.to_datetime(df['Date_time']).dt.hour.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Data Transformation

# %%
df['Rating']
# Out:
# 0      9.1
# 1      9.6
# 2      7.4
# 3      8.4
# 4      5.3
#       ...
# 995    6.2
# 996    4.4
# 997    7.7
# 998    4.1
# 999    6.6
# Name: Rating, Length: 1000, dtype: float64

# %%
pd.cut(df['Rating'],bins=3)
# Out:
# 0       (8.0, 10.0]
# 1       (8.0, 10.0]
# 2        (6.0, 8.0]
# 3       (8.0, 10.0]
# 4      (3.994, 6.0]
#            ...
# 995      (6.0, 8.0]
# 996    (3.994, 6.0]
# 997      (6.0, 8.0]
# 998    (3.994, 6.0]
# 999      (6.0, 8.0]
# Name: Rating, Length: 1000, dtype: category
# Categories (3, interval[float64]): [(3.994, 6.0] < (6.0, 8.0] < (8.0, 10.0]]

# %%
pd.cut(df['Rating'],bins=[3,6,8])
# Out:
# 0             NaN
# 1             NaN
# 2      (6.0, 8.0]
# 3             NaN
# 4      (3.0, 6.0]
#           ...
# 995    (6.0, 8.0]
# 996    (3.0, 6.0]
# 997    (6.0, 8.0]
# 998    (3.0, 6.0]
# 999    (6.0, 8.0]
# Name: Rating, Length: 1000, dtype: category
# Categories (2, interval[int64]): [(3, 6] < (6, 8]]

# %%
pd.cut(df['Rating'],bins=[3,6,9,10])
# Out:
# 0      (9, 10]
# 1      (9, 10]
# 2       (6, 9]
# 3       (6, 9]
# 4       (3, 6]
#         ...
# 995     (6, 9]
# 996     (3, 6]
# 997     (6, 9]
# 998     (3, 6]
# 999     (6, 9]
# Name: Rating, Length: 1000, dtype: category
# Categories (3, interval[int64]): [(3, 6] < (6, 9] < (9, 10]]

# %%
pd.cut(df['Rating'],bins=[3,6,9,10] , labels=['Bad','Good','Excellent'])
# Out:
# 0      Excellent
# 1      Excellent
# 2           Good
# 3           Good
# 4            Bad
#          ...
# 995         Good
# 996          Bad
# 997         Good
# 998          Bad
# 999         Good
# Name: Rating, Length: 1000, dtype: category
# Categories (3, object): ['Bad' < 'Good' < 'Excellent']

# %%
df['Rating_bin']=pd.cut(df['Rating'],bins=[3,6,9,10],labels=(['Bad','Good','Excellent']))

# %%
df['gross margin percentage']
# Out:
# 0      4.761905
# 1      4.761905
# 2      4.761905
# 3      4.761905
# 4      4.761905
#          ...
# 995    4.761905
# 996    4.761905
# 997    4.761905
# 998    4.761905
# 999    4.761905
# Name: gross margin percentage, Length: 1000, dtype: float64

# %%
pd.cut(df['gross margin percentage'],bins=[1,3,6,8] , labels=['low','average','High'])
# Out:
# 0      average
# 1      average
# 2      average
# 3      average
# 4      average
#         ...
# 995    average
# 996    average
# 997    average
# 998    average
# 999    average
# Name: gross margin percentage, Length: 1000, dtype: category
# Categories (3, object): ['low' < 'average' < 'High']

# %%
df['gross income']
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: gross income, Length: 1000, dtype: float64

# %%
pd.cut(df['gross income'],bins=3)
# Out:
# 0      (16.889, 33.27]
# 1      (0.459, 16.889]
# 2      (0.459, 16.889]
# 3      (16.889, 33.27]
# 4      (16.889, 33.27]
#             ...
# 995    (0.459, 16.889]
# 996     (33.27, 49.65]
# 997    (0.459, 16.889]
# 998    (0.459, 16.889]
# 999    (16.889, 33.27]
# Name: gross income, Length: 1000, dtype: category
# Categories (3, interval[float64]): [(0.459, 16.889] < (16.889, 33.27] < (33.27, 49.65]]

# %%
pd.cut(df['gross income'],bins=[1,15,30,50] , labels=['low','average','High'])
# Out:
# 0      average
# 1          low
# 2      average
# 3      average
# 4         High
#         ...
# 995        low
# 996       High
# 997        low
# 998        low
# 999       High
# Name: gross income, Length: 1000, dtype: category
# Categories (3, object): ['low' < 'average' < 'High']

# %% [markdown]
# ###  Exploratory Data Analysis

# %%
sns.catplot(data=df , x='Unit price' , col = 'Gender' , kind='box') #15th April 2021

# %%
sns.catplot( data=df, x= 'Total' , col='Customer type' , kind='violin')

# %%
sns.catplot(data=df , x='Unit price' , y='Total',hue = 'Gender' , kind='point')

# %%
sns.catplot(data=df , x='Unit price' , y='Total',col = 'Gender' , kind='point')

# %%
sns.catplot(data=df , x='cogs' , y='Total',col = 'Gender' , kind='point')

# %%
sns.catplot(data=df , x='cogs' ,col = 'Gender' , kind='swarm')

# %%
list_df=['Branch', 'City', 'Customer type', 'Gender',
       'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Payment', 'cogs', 'gross margin percentage', 'gross income']

# %%
sns.pairplot(data=df[list_df])

# %%
sns.countplot(data=df,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x='Gender', hue='Rating_bin')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.catplot(data=df,x='Gender', hue='Rating_bin', row='Product line',kind='count')

# %% [markdown]
# ### Data Normalization

# %%
(df['gross income']-df['gross income'].min())/(df['gross income'].max()-df['gross income'].min())
# Out:
# 0      0.521616
# 1      0.067387
# 2      0.319628
# 3      0.463549
# 4      0.604377
#          ...
# 995    0.030707
# 996    0.980465
# 997    0.022049
# 998    0.056622
# 999    0.618835
# Name: gross income, Length: 1000, dtype: float64

# %%
def min_max(data,columns):
    data[str(columns)]=(data[str(columns)] - data[str(columns)].min())/(data[str(columns)].max()-data[str(columns)].min())

num_df=df.select_dtypes(include=[float,int])

list_num_cols=list(num_df.columns)

list_num_cols
# Out:
# ['Unit price',
#  'Tax 5%',
#  'Total',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating']

# %%
for cols in list_num_cols:
    
    min_max(df,cols)
    
df['Unit price'].sample(10)
# Out:
# 862    0.013351
# 234    0.465732
# 984    0.960058
# 269    0.283267
# 863    0.456053
# 236    0.081553
# 310    0.777147
# 536    0.710725
# 141    0.894749
# 219    0.525812
# Name: Unit price, dtype: float64

# %%
def min_max(col):
    min_val = np.min(col)
    max_val = np.max(col)
    col= (col-min_val) / (max_val-min_val)
    return col
min_max(df['gross income'])
# Out:
# 0      0.521616
# 1      0.067387
# 2      0.319628
# 3      0.463549
# 4      0.604377
#          ...
# 995    0.030707
# 996    0.980465
# 997    0.022049
# 998    0.056622
# 999    0.618835
# Name: gross income, Length: 1000, dtype: float64

# %%
import sklearn.preprocessing as pre
le=pre.LabelEncoder()

# %%
for x in list_df:
    df[x]=le.fit_transform(df[x])

# %%
le.fit(df['Product line'])
# Out:
# LabelEncoder()

# %%
le.transform(df['Product line'])
# Out:
# array([3, 0, 4, 3, 5, 0, 0, 4, 3, 2, 1, 0, 0, 2, 3, 5, 3, 5, 2, 4, 0, 3,
#        4, 0, 5, 4, 1, 1, 2, 3, 1, 5, 5, 3, 2, 5, 5, 0, 3, 4, 4, 4, 5, 2,
#        3, 0, 3, 2, 0, 1, 2, 2, 1, 1, 4, 0, 4, 3, 4, 0, 5, 4, 5, 5, 3, 3,
#        3, 1, 5, 3, 2, 1, 2, 0, 4, 0, 1, 1, 2, 3, 3, 2, 2, 2, 5, 5, 1, 2,
#        5, 3, 4, 5, 5, 3, 3, 0, 3, 0, 2, 4, 1, 1, 0, 2, 3, 0, 1, 5, 2, 0,
#        5, 3, 1, 4, 4, 1, 1, 1, 2, 4, 0, 5, 5, 4, 1, 4, 5, 1, 2, 5, 1, 5,
#        5, 0, 3, 1, 0, 4, 5, 5, 5, 3, 3, 2, 4, 3, 1, 3, 4, 3, 1, 5, 1, 2,
#        5, 2, 0, 4, 3, 5, 2, 5, 2, 5, 2, 3, 4, 1, 2, 5, 3, 2, 0, 0, 2, 4,
#        2, 1, 2, 3, 1, 2, 5, 3, 5, 2, 4, 4, 4, 4, 4, 1, 2, 4, 0, 1, 3, 4,
#        3, 2, 5, 0, 0, 3, 4, 3, 0, 4, 1, 0, 0, 2, 4, 5, 5, 4, 5, 0, 1, 2,
#        0, 2, 0, 1, 2, 5, 3, 0, 0, 4, 1, 0, 3, 1, 3, 5, 3, 1, 0, 1, 2, 3,
#        1, 4, 4, 4, 0, 1, 0, 2, 2, 1, 5, 4, 4, 1, 0, 4, 0, 0, 0, 1, 1, 5,
#        5, 5, 4, 2, 4, 4, 5, 3, 4, 4, 3, 1, 4, 1, 1, 5, 4, 4, 5, 3, 3, 3,
#        4, 5, 2, 4, 0, 0, 0, 2, 3, 0, 0, 4, 4, 4, 1, 3, 2, 0, 0, 0, 5, 4,
#        0, 1, 5, 1, 2, 3, 0, 2, 2, 0, 3, 3, 2, 3, 3, 1, 4, 5, 2, 2, 3, 0,
#        4, 2, 1, 2, 5, 0, 1, 5, 0, 2, 0, 3, 3, 2, 5, 1, 0, 4, 0, 3, 1, 0,
#        1, 4, 0, 2, 1, 5, 0, 5, 2, 2, 2, 4, 2, 1, 0, 4, 5, 0, 0, 1, 4, 1,
#        4, 1, 4, 5, 1, 0, 5, 0, 2, 2, 2, 5, 2, 3, 1, 2, 1, 1, 0, 5, 3, 3,
#        2, 4, 3, 0, 2, 4, 4, 1, 1, 5, 2, 1, 4, 1, 3, 5, 3, 5, 4, 3, 4, 3,
#        3, 0, 2, 0, 1, 1, 1, 1, 3, 2, 5, 4, 1, 2, 0, 1, 1, 5, 5, 4, 2, 0,
#        2, 5, 4, 1, 5, 3, 2, 1, 3, 5, 0, 0, 2, 3, 0, 1, 2, 0, 0, 2, 2, 2,
#        5, 2, 2, 5, 3, 5, 2, 0, 4, 5, 1, 3, 0, 3, 5, 0, 5, 0, 2, 0, 5, 4,
#        5, 5, 1, 1, 4, 4, 1, 1, 3, 4, 1, 5, 0, 2, 5, 5, 5, 1, 4, 5, 5, 0,
#        5, 2, 3, 4, 5, 4, 1, 0, 5, 1, 3, 4, 4, 5, 0, 4, 4, 3, 2, 5, 1, 1,
#        2, 5, 3, 1, 0, 2, 4, 4, 1, 4, 1, 2, 4, 3, 5, 0, 2, 4, 1, 5, 5, 0,
#        1, 1, 3, 0, 0, 4, 1, 2, 2, 4, 0, 2, 0, 0, 1, 2, 5, 1, 1, 5, 4, 5,
#        2, 2, 5, 1, 2, 2, 3, 3, 2, 3, 1, 1, 5, 3, 2, 5, 1, 3, 3, 4, 5, 5,
#        5, 3, 2, 5, 1, 4, 0, 1, 2, 5, 1, 4, 1, 2, 1, 2, 0, 2, 1, 5, 2, 5,
#        5, 0, 2, 1, 2, 2, 4, 1, 1, 2, 5, 3, 4, 1, 5, 0, 2, 4, 2, 3, 3, 0,
#        2, 1, 2, 0, 0, 2, 0, 4, 3, 1, 5, 0, 0, 3, 4, 5, 1, 0, 0, 1, 5, 1,
#        5, 5, 1, 2, 5, 1, 2, 3, 3, 5, 1, 2, 3, 3, 0, 1, 5, 2, 3, 2, 0, 5,
#        1, 1, 5, 4, 5, 4, 5, 2, 5, 2, 3, 1, 2, 4, 5, 4, 0, 4, 1, 2, 1, 3,
#        4, 3, 0, 2, 1, 5, 2, 4, 0, 3, 1, 3, 1, 0, 1, 1, 1, 5, 4, 2, 2, 3,
#        4, 5, 1, 4, 1, 3, 1, 0, 2, 3, 4, 0, 0, 4, 4, 2, 5, 4, 5, 2, 1, 4,
#        4, 3, 1, 2, 0, 4, 1, 1, 0, 4, 2, 2, 2, 0, 1, 3, 3, 4, 1, 5, 0, 4,
#        5, 3, 5, 2, 2, 2, 3, 5, 5, 0, 3, 5, 1, 4, 3, 0, 0, 3, 3, 5, 1, 3,
#        4, 0, 0, 1, 4, 5, 3, 4, 5, 0, 1, 1, 0, 4, 5, 0, 3, 1, 3, 0, 5, 0,
#        0, 2, 1, 2, 3, 2, 0, 4, 5, 3, 5, 5, 3, 1, 0, 0, 0, 3, 5, 3, 4, 1,
#        1, 5, 0, 5, 1, 0, 5, 2, 1, 0, 0, 5, 2, 1, 1, 1, 3, 0, 3, 1, 2, 4,
#        3, 2, 4, 5, 4, 4, 0, 3, 5, 3, 2, 5, 2, 1, 0, 5, 4, 4, 1, 0, 0, 0,
#        2, 1, 5, 4, 2, 5, 2, 0, 1, 5, 3, 0, 1, 0, 0, 3, 1, 2, 3, 2, 0, 4,
#        3, 2, 3, 4, 3, 3, 2, 4, 2, 0, 4, 1, 2, 0, 5, 1, 4, 0, 4, 4, 4, 5,
#        5, 0, 5, 3, 0, 5, 4, 1, 2, 3, 4, 4, 3, 5, 3, 2, 2, 1, 4, 3, 3, 0,
#        0, 1, 4, 2, 3, 4, 2, 2, 4, 1, 2, 0, 4, 2, 1, 0, 1, 0, 2, 0, 4, 4,
#        3, 0, 2, 4, 0, 4, 1, 1, 2, 2, 0, 2, 2, 3, 5, 3, 0, 1, 3, 3, 0, 3,
#        2, 5, 0, 1, 0, 3, 4, 2, 4, 1], dtype=int64)

# %%
df_ML=df[list_df]   
df_test=df_ML.copy

# %% [markdown]
# ## Model Building - KNN

# %%
df_test=pre.minmax_scale(df_ML.values)

# %%
#df_Norm=pre.minmax_scale(df_ML.values)

# %%
df_Norm=pd.DataFrame(data=df_test, columns=df_ML.columns.to_list())

# %%
features=df_Norm.drop('Total',axis=1)
outcome=df_Norm['Total']

# %%
import sklearn.model_selection as ms

# %%
#Splitting the dataset into train and test
x_train,x_test,y_train,y_test=ms.train_test_split(features,outcome,test_size=0.3,random_state=1234561)

# %%
#Checking the shape of the test & train dataset
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((700, 12), (300, 12), (700,), (300,))

# %%
import sklearn.neighbors as NN

# %%
KNN=NN.KNeighborsRegressor(n_neighbors=5,weights='distance', metric='minkowski')

# %%
#Fitting the model
KNN.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(weights='distance')

# %%
#checking the predicted values
KNN.predict(x_test)
# Out:
# array([0.70386696, 0.52470152, 0.34734906, 0.77196352, 0.77542002,
#        0.72274436, 0.62400721, 0.40463922, 0.72186894, 0.16021975,
#        0.21666684, 0.12733467, 0.26500647, 0.20711126, 0.16863338,
#        0.81666149, 0.74672229, 0.15072547, 0.36736187, 0.29752983,
#        0.52643705, 0.42302522, 0.58501116, 0.36568688, 0.8490932 ,
#        0.9604763 , 0.82759233, 0.3789512 , 0.72496869, 0.5761361 ,
#        0.17494731, 0.80532274, 0.72518224, 0.78451419, 0.3774841 ,
#        0.34133273, 0.26465769, 0.53100196, 0.92602435, 0.57667292,
#        0.46618466, 0.86462961, 0.37207067, 0.75335128, 0.67588957,
#        0.2953479 , 0.09861695, 0.44766471, 0.59971178, 0.45196252,
#        0.87277907, 0.50659237, 0.84326613, 0.19188825, 0.51892759,
#        0.74998955, 0.17374983, 0.07527345, 0.69338502, 0.1885206 ,
#        0.75959907, 0.19968309, 0.4863484 , 0.60870524, 0.03535024,
#        0.28052025, 0.56984491, 0.60413609, 0.40078475, 0.74406401,
#        0.16146284, 0.64938108, 0.42090593, 0.73677394, 0.78354492,
#        0.26584656, 0.68839255, 0.14757972, 0.78659403, 0.22623294,
#        0.13241968, 0.41387541, 0.46170838, 0.45783719, 0.04145431,
#        0.37063836, 0.1334223 , 0.27143962, 0.26750504, 0.3693846 ,
#        0.92506786, 0.93051598, 0.82091891, 0.83062521, 0.45783392,
#        0.47116344, 0.30503133, 0.82758338, 0.22919392, 0.75654998,
#        0.46691096, 0.06576369, 0.31677905, 0.53873549, 0.92994304,
#        0.41909269, 0.55971723, 0.69967435, 0.1835393 , 0.6314087 ,
#        0.21041543, 0.26369526, 0.46522313, 0.22480229, 0.16028495,
#        0.15609084, 0.52111415, 0.85300295, 0.92827302, 0.8944295 ,
#        0.94235348, 0.76008618, 0.18853097, 0.19825221, 0.17434971,
#        0.14474518, 0.64458997, 0.33273517, 0.90700086, 0.34383611,
#        0.41779227, 0.68054981, 0.48631114, 0.29668819, 0.8472797 ,
#        0.60085555, 0.11592377, 0.41940226, 0.31840998, 0.92898423,
#        0.72326172, 0.28658943, 0.89682139, 0.12108335, 0.79758161,
#        0.30442222, 0.25463142, 0.46542329, 0.87454684, 0.83362898,
#        0.48658327, 0.55071667, 0.59362596, 0.31911213, 0.54607242,
#        0.35524439, 0.28029261, 0.75201515, 0.16743415, 0.82898363,
#        0.0877944 , 0.93092475, 0.78775232, 0.88167333, 0.557287  ,
#        0.65659487, 0.72244797, 0.13510444, 0.40943817, 0.2486572 ,
#        0.41266669, 0.58181671, 0.25914209, 0.64416008, 0.88385933,
#        0.16035447, 0.70862312, 0.32905617, 0.03511012, 0.79272348,
#        0.14235882, 0.92452829, 0.81486273, 0.81390571, 0.70650677,
#        0.61219892, 0.5920656 , 0.03488251, 0.27085662, 0.15237469,
#        0.24449609, 0.46432239, 0.12994875, 0.89982972, 0.21466123,
#        0.90505774, 0.62938704, 0.91421896, 0.88094836, 0.45744174,
#        0.14161989, 0.17300715, 0.92416659, 0.11036666, 0.50935248,
#        0.20069332, 0.36784601, 0.67256926, 0.37857806, 0.91495343,
#        0.88488273, 0.27829844, 0.65618688, 0.75547121, 0.19336676,
#        0.1983253 , 0.74492775, 0.20292698, 0.69434578, 0.79107705,
#        0.27893663, 0.20199688, 0.52820908, 0.2469134 , 0.84697325,
#        0.28451273, 0.46414777, 0.50707893, 0.33318713, 0.82237234,
#        0.14149574, 0.35041193, 0.45515869, 0.43688285, 0.57593856,
#        0.17599539, 0.45361391, 0.09806788, 0.35844758, 0.37190299,
#        0.69411502, 0.7850154 , 0.61737634, 0.16275087, 0.69809463,
#        0.51268379, 0.62100727, 0.08948179, 0.85252804, 0.14372782,
#        0.54656544, 0.7584767 , 0.89782007, 0.76613666, 0.16532839,
#        0.41003938, 0.38906173, 0.88516459, 0.45206874, 0.35788191,
#        0.25088032, 0.72162385, 0.32160613, 0.1627324 , 0.92555603,
#        0.36402006, 0.89483522, 0.67380181, 0.27279125, 0.10974657,
#        0.86228585, 0.57419808, 0.35537943, 0.4167095 , 0.16322968,
#        0.60484384, 0.15772907, 0.69570988, 0.45320133, 0.88148314,
#        0.20675239, 0.38714475, 0.98132467, 0.14927885, 0.70336093,
#        0.74935125, 0.49063125, 0.31032323, 0.42208835, 0.08398826,
#        0.75627252, 0.43996017, 0.39510301, 0.21977858, 0.94761604,
#        0.90153766, 0.93178531, 0.77728242, 0.89655078, 0.75810183])

# %%
#checking the test score
KNN.score(x_test,y_test)
# Out:
# 0.9433148213869806

# %%
#checking the train score
KNN.score(x_train,y_train)
# Out:
# 1.0

# %% [markdown]
# ##### n=6

# %%
KNN=NN.KNeighborsRegressor(n_neighbors=6,weights='distance', metric='minkowski')

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=6, weights='distance')

# %%
KNN.predict(x_test)
# Out:
# array([0.66434829, 0.52520168, 0.36599007, 0.73685477, 0.78965754,
#        0.72674714, 0.61829147, 0.42155957, 0.71958521, 0.18803933,
#        0.23093304, 0.12837259, 0.22724856, 0.19201316, 0.19549827,
#        0.78751767, 0.73637891, 0.16273293, 0.39092254, 0.35296506,
#        0.49464084, 0.43825759, 0.56251568, 0.36545933, 0.85314067,
#        0.95139668, 0.84346456, 0.38076648, 0.72815341, 0.59473576,
#        0.16212684, 0.8195538 , 0.72585699, 0.73095418, 0.39007806,
#        0.37985214, 0.27944752, 0.54299507, 0.91536452, 0.59546338,
#        0.48647112, 0.86513254, 0.40500114, 0.7586029 , 0.63132349,
#        0.28705844, 0.10446933, 0.44521098, 0.60061471, 0.46055223,
#        0.87065588, 0.48197444, 0.85079502, 0.20465745, 0.53830057,
#        0.75721114, 0.1666421 , 0.10694637, 0.65839468, 0.22902661,
#        0.77938885, 0.23231458, 0.44081844, 0.66463294, 0.04049035,
#        0.2687279 , 0.57204128, 0.5942462 , 0.43077286, 0.76642765,
#        0.18738934, 0.63768575, 0.42541183, 0.76758274, 0.77440236,
#        0.27493554, 0.66039704, 0.14035657, 0.79459587, 0.23963981,
#        0.15172952, 0.40891359, 0.49050325, 0.48258689, 0.05024025,
#        0.34940192, 0.1175929 , 0.23488143, 0.25440225, 0.35773691,
#        0.91532197, 0.92332347, 0.82646647, 0.84031169, 0.45812326,
#        0.46060631, 0.29326468, 0.83190675, 0.20415922, 0.76599777,
#        0.43159378, 0.08007225, 0.31142445, 0.53801011, 0.90529789,
#        0.4158982 , 0.53531024, 0.69356926, 0.19748339, 0.6037807 ,
#        0.23463484, 0.24853108, 0.44050068, 0.1997199 , 0.19136826,
#        0.18462687, 0.51707533, 0.87320101, 0.90905636, 0.88145168,
#        0.92998372, 0.73716594, 0.18712478, 0.22165589, 0.18653565,
#        0.13816048, 0.66643607, 0.33591608, 0.88013208, 0.32847513,
#        0.38653498, 0.70169143, 0.49999007, 0.2685645 , 0.82256423,
#        0.62809808, 0.12410354, 0.36966259, 0.30228141, 0.92749766,
#        0.70204963, 0.28184729, 0.90748784, 0.16138709, 0.76464573,
#        0.31837516, 0.27650993, 0.48564284, 0.87193043, 0.8370289 ,
#        0.48505208, 0.54238856, 0.5840611 , 0.31520298, 0.55586873,
#        0.33005341, 0.26613962, 0.77553847, 0.18045339, 0.80562917,
#        0.09042761, 0.91205155, 0.7883412 , 0.85745171, 0.54390668,
#        0.63852017, 0.70122945, 0.14303515, 0.38001445, 0.26458083,
#        0.41751187, 0.59684254, 0.28839232, 0.61058681, 0.88627405,
#        0.16825436, 0.69919877, 0.32212246, 0.04117252, 0.76986111,
#        0.13955699, 0.92794053, 0.83255837, 0.81081809, 0.69255378,
#        0.60770881, 0.60941859, 0.03625   , 0.25806604, 0.13743201,
#        0.22893706, 0.43406439, 0.12490699, 0.89819017, 0.2029308 ,
#        0.89113375, 0.65883037, 0.91390504, 0.86630383, 0.45971687,
#        0.12868289, 0.19492638, 0.91724425, 0.10825366, 0.5324423 ,
#        0.22096784, 0.35138017, 0.64664091, 0.40722184, 0.88441336,
#        0.8749473 , 0.27866495, 0.64504848, 0.7796203 , 0.17109634,
#        0.17981775, 0.75538252, 0.21949463, 0.68742716, 0.76861647,
#        0.25754787, 0.23698356, 0.52847168, 0.24750743, 0.85155058,
#        0.30719072, 0.50759292, 0.5014252 , 0.30025635, 0.83762489,
#        0.13660044, 0.35173557, 0.43302137, 0.4082435 , 0.59132919,
#        0.1540806 , 0.41584656, 0.10122067, 0.33809293, 0.35856547,
#        0.66769015, 0.80672542, 0.61025815, 0.15126827, 0.69396869,
#        0.51254739, 0.63717142, 0.10821878, 0.824113  , 0.14703905,
#        0.54275859, 0.75636434, 0.88311418, 0.76715332, 0.17451548,
#        0.39271492, 0.35551415, 0.8611906 , 0.46825634, 0.32468392,
#        0.25670618, 0.73791598, 0.33226518, 0.1569824 , 0.92717517,
#        0.37423547, 0.88607974, 0.65400927, 0.29413554, 0.10857587,
#        0.87072329, 0.60293903, 0.3593953 , 0.43603533, 0.15860277,
#        0.63511848, 0.14769267, 0.67673267, 0.47358882, 0.88433168,
#        0.17921559, 0.3333798 , 0.97608816, 0.12864465, 0.68604427,
#        0.77392735, 0.52043534, 0.3536764 , 0.41788876, 0.08235439,
#        0.76030447, 0.4093045 , 0.40175925, 0.22210307, 0.93154967,
#        0.89952415, 0.93642135, 0.75448486, 0.89365591, 0.76382229])

# %%
KNN.score(x_test,y_test)
# Out:
# 0.947026621641414

# %%
KNN.score(x_train,y_train)
# Out:
# 1.0

# %% [markdown]
# ##### n = 15

# %%
KNN=NN.KNeighborsRegressor(n_neighbors=15,weights='distance', metric='minkowski')

# %%
#Fitting the model
KNN.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=15, weights='distance')

# %%
#checking the predicted value
KNN.predict(x_test)
# Out:
# array([0.64432636, 0.54123129, 0.31618472, 0.75507493, 0.7694521 ,
#        0.62990251, 0.65833691, 0.39011882, 0.78417701, 0.24891526,
#        0.26228776, 0.16374631, 0.18626313, 0.25182217, 0.2125461 ,
#        0.75122186, 0.72426911, 0.18778619, 0.39966236, 0.40144991,
#        0.54704306, 0.43371116, 0.56354477, 0.34556156, 0.84714269,
#        0.91558089, 0.83855307, 0.36575403, 0.71622271, 0.59751365,
#        0.21576652, 0.69259209, 0.74949626, 0.72366328, 0.32461967,
#        0.3197435 , 0.30090068, 0.51006847, 0.8610142 , 0.57821761,
#        0.45729058, 0.85748033, 0.39975605, 0.73189894, 0.60965265,
#        0.37909894, 0.21130434, 0.4622974 , 0.62116352, 0.44934681,
#        0.83474999, 0.46903215, 0.81263086, 0.25705616, 0.44220582,
#        0.76475983, 0.23733158, 0.18560195, 0.64788855, 0.22926955,
#        0.73973802, 0.26016087, 0.41706385, 0.68790879, 0.06863465,
#        0.2513776 , 0.50839863, 0.53895364, 0.34003236, 0.78658789,
#        0.23156434, 0.61608858, 0.48504347, 0.73073696, 0.79854779,
#        0.25768283, 0.63586934, 0.17947025, 0.806058  , 0.25140659,
#        0.16209044, 0.40300682, 0.46667856, 0.45777097, 0.10708189,
#        0.31123165, 0.18558213, 0.25112834, 0.34782863, 0.40761863,
#        0.88215516, 0.85621774, 0.82121419, 0.81490464, 0.48184419,
#        0.48535926, 0.31505627, 0.85068443, 0.20792482, 0.75031562,
#        0.47163362, 0.12112779, 0.32320317, 0.62455009, 0.90776906,
#        0.40557354, 0.56789191, 0.71502164, 0.28238353, 0.61802265,
#        0.2202001 , 0.30282089, 0.43292027, 0.20470208, 0.20402916,
#        0.23295154, 0.50846468, 0.86676111, 0.88674247, 0.79718304,
#        0.87911673, 0.70494457, 0.23708438, 0.30450442, 0.19958278,
#        0.16068648, 0.6441014 , 0.35446917, 0.85397136, 0.35545547,
#        0.43491774, 0.69169314, 0.49545523, 0.28996472, 0.77044598,
#        0.51866245, 0.15443509, 0.38940439, 0.30339635, 0.86170494,
#        0.69164069, 0.30654298, 0.83844091, 0.27983907, 0.72361497,
#        0.29311482, 0.29771802, 0.47891286, 0.80959988, 0.84456038,
#        0.43410618, 0.49402337, 0.59027546, 0.3153515 , 0.59487196,
#        0.35284052, 0.3525948 , 0.78900319, 0.21989347, 0.80311515,
#        0.14419129, 0.85641216, 0.69190369, 0.83051476, 0.48715129,
#        0.62256995, 0.68384593, 0.17596858, 0.38213214, 0.25904686,
#        0.41650231, 0.64200394, 0.37642915, 0.67405155, 0.86625054,
#        0.1776964 , 0.69387414, 0.32989062, 0.09431514, 0.76352265,
#        0.183289  , 0.90066967, 0.77855981, 0.77017075, 0.69395408,
#        0.57757673, 0.65293853, 0.10029936, 0.27244587, 0.18643511,
#        0.24629547, 0.33572013, 0.13606967, 0.86350597, 0.27510843,
#        0.88949303, 0.65254717, 0.85792039, 0.8169584 , 0.5119936 ,
#        0.2815699 , 0.20088559, 0.84789109, 0.12645836, 0.53607301,
#        0.22534405, 0.29120008, 0.62819252, 0.45647702, 0.83497552,
#        0.82596958, 0.27406955, 0.68276451, 0.73304774, 0.20941511,
#        0.20591879, 0.78136638, 0.29593888, 0.68648889, 0.70464996,
#        0.27678283, 0.28308   , 0.54539653, 0.28441803, 0.82510317,
#        0.26413712, 0.58748173, 0.5290705 , 0.2894504 , 0.81180384,
#        0.14009   , 0.36060976, 0.40704164, 0.42000128, 0.59375157,
#        0.21524752, 0.43941061, 0.14219876, 0.3100865 , 0.2582756 ,
#        0.59635166, 0.76634562, 0.57727883, 0.24857515, 0.68650726,
#        0.48267351, 0.63294041, 0.14998057, 0.8356503 , 0.15755509,
#        0.54328055, 0.72281974, 0.83420513, 0.76404039, 0.24925266,
#        0.44436787, 0.41153892, 0.86329089, 0.47424483, 0.37466679,
#        0.26429338, 0.71123684, 0.26318003, 0.17723442, 0.86281775,
#        0.31911838, 0.82491995, 0.6460519 , 0.31407082, 0.16704817,
#        0.81747237, 0.55403448, 0.36713516, 0.40599075, 0.2079786 ,
#        0.66183839, 0.17920035, 0.68719033, 0.46803284, 0.85562621,
#        0.18581312, 0.26861074, 0.95273176, 0.13210997, 0.57877391,
#        0.74464279, 0.47780076, 0.32446329, 0.47098625, 0.1312761 ,
#        0.74221517, 0.45253132, 0.34887003, 0.25958322, 0.89801823,
#        0.81433603, 0.92068242, 0.76962712, 0.87582334, 0.76706011])

# %%
#Checking the test scores
KNN.score(x_test,y_test)
# Out:
# 0.9383136901977973

# %%
#Checking the train scores
KNN.score(x_train,y_train)
# Out:
# 1.0

# %%
#Removing some selected features
exp_1=features.drop(['Unit price','Quantity'],axis=1)

# %%
x_train_1,x_test_1,y_train_1,y_test_1=ms.train_test_split(exp_1,outcome,test_size=0.3,random_state=1234561)

# %%
KNN_1=NN.KNeighborsRegressor(n_neighbors=5,metric='minkowski')

# %%
#fitting the model
KNN_1.fit(x_train_1,y_train_1)
# Out:
# KNeighborsRegressor()

# %%
#Checking the test scores
KNN_1.score(x_train_1,y_train_1)
# Out:
# 0.9524743779207295

# %%
#importing library
import sklearn.metrics as mt

# %%
#checking MSE for test values
mt.mean_squared_error(y_pred=KNN_1.predict(x_test_1),y_true=y_test_1)
# Out:
# 0.006204295651219703

# %%
#checking MSE for train values
mt.mean_squared_error(y_pred=KNN_1.predict(x_train_1),y_true=y_train_1)
# Out:
# 0.0038635622498940027
